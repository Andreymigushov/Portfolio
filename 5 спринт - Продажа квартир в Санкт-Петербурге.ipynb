# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Инструкция по выполнению проекта**
#
# *Шаг 1. Откройте файл с данными и изучите общую информацию*
# Загрузите данные из csv-файла в датафрейм c помощью библиотеки pandas.
# Изучите общую информацию о полученном датафрейме.
# Постройте гистограмму для всех числовых столбцов таблицы на одном графике. Например, для датафрейма data можно построить такую гистограмму командой data.hist(figsize=(15, 20)). Напомним, что параметр figsize задаёт размер графика.
#
# *Шаг 2. Выполните предобработку данных*
# Найдите и изучите пропущенные значения в столбцах:
# Определите, в каких столбцах есть пропуски.
# Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски можно заменить на число 0. Если логичную замену предложить невозможно, то оставьте пропуски.   Пропущенные значения — тоже важный сигнал, который нужно учитывать
# В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.
# Рассмотрите типы данных в каждом столбце
# Найдите столбцы, в которых нужно изменить тип данных.
# Преобразуйте тип данных в выбранных столбцах.
# В ячейке с типом markdown поясните, почему нужно изменить тип данных.
# Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
#
# *Шаг 3. Добавьте в таблицу новые столбцы со следующими параметрами:*
# цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# месяц публикации объявления;
# год публикации объявления;
# тип этажа квартиры (значения — «первый», «последний», «другой»);
# расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).
#
# *Шаг 4. Проведите исследовательский анализ данных:*
# Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров.
# В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите корректное значение. В противном случае удалите редкие и выбивающиеся значения
# Список параметров
# общая площадь;
# жилая площадь;
# площадь кухни;
# цена объекта;
# количество комнат;
# высота потолков;
# тип этажа квартиры («первый», «последний», «другой»);
# общее количество этажей в доме;
# расстояние до центра города в метрах;
# расстояние до ближайшего парка.
# Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
# Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
# Постройте гистограмму.
# Посчитайте среднее и медиану.
# В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
# Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
# Изучите, зависит ли цена от:
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.
#
# *Шаг 5. Напишите общий вывод.*
# Опишите полученные результаты и зафиксируйте итоговый вывод проведённого исследования.

# %% [markdown]
# **Описание данных**
#
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# balcony — число балконов
# ceiling_height — высота потолков (м)
# cityCenters_nearest — расстояние до центра города (м)
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# first_day_exposition — дата публикации
# floor — этаж
# floors_total — всего этажей в доме
# is_apartment — апартаменты (булев тип)
# kitchen_area — площадь кухни в квадратных метрах (м²)
# last_price — цена на момент снятия с публикации
# living_area — жилая площадь в квадратных метрах (м²)
# locality_name — название населённого пункта
# open_plan — свободная планировка (булев тип)
# parks_around3000 — число парков в радиусе 3 км
# parks_nearest — расстояние до ближайшего парка (м)
# ponds_around3000 — число водоёмов в радиусе 3 км
# ponds_nearest — расстояние до ближайшего водоёма (м)
# rooms — число комнат
# studio — квартира-студия (булев тип)
# total_area — общая площадь квартиры в квадратных метрах (м²)
# total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ### Откроем файл с данными и изучим общую информацию.

# %% [markdown]
# Импорт всех необходимых библиотек.

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Загрузим данные и выведем первые пять строк датафрейма.

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Построим общую гистограмму для всех числовых столбцов таблицы.

# %%
data.hist(figsize=(15, 20)) 
plt.show()

# %% [markdown]
# По имеющимся данным попробуем из некоторых гистограмм сделать определенные предварительные выводы:
# total_images (число фотографий квартиры в объявлении) - чаще встречаются в объявлениях от 5 до 15 фотографий;
# balcony (число балконов квартиры в объявлении) - чаще встречаются квартиры с 1 балконом, но и не редки случаи вариантов без балкона и с 2-мя балконами;
# parks_around3000 (число парков в радиусе 3 км) - чаще встречаются объявления с около нулевым значением парков в радиусе 3000 метров от продаваемой квартиры;
# ponds_around3000 (число водоемов в радиусе 3 км) - чаще встречаются объявления с около нулевым значением водоемов в радиусе 3000 метров от продаваемой квартиры.

# %% [markdown]
#  Выведем основную информацию о датафрейме.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Переименуем столбцы:

# %%
data.rename(columns={'cityCenters_nearest' : 'city_centers_nearest'}, inplace=True)
data.rename(columns={'parks_around3000' : 'parks_around_3000'}, inplace=True)
data.rename(columns={'ponds_around3000' : 'ponds_around_3000'}, inplace=True)

# %% [markdown]
#  Выведем количество пропущенных значений для каждого столбца.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Анализ пропущеных значений.

# %% [markdown]
# В столбце "ceiling_height" количество пропущенных значений высоты потолков занимает около 38,8 %.
# Эти значения скорее всего просто забыли заполнить. Для расчетов заменим их медианное значение.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# В столбце "floors_total" количество пропущенных значений этажей в доме занимает около 0,36 %.
# Доля этих значений крайне мала. Удалим эти строки.

# %%
data = data.dropna(subset=['floors_total'])

# %% [markdown]
# В столбце "living_area" количество пропущенных значений жилой площади в квартирах занимает около 8 %.
# Данные просто не заполнили, оставим NaN.

# %% [markdown]
# В столбце "is_apartment" количество пропущенных значений занимает около 88,3 %.
# Предположим, что это не ошибка и подразумевалось, что это не апартаменты. Присваиваем этим значениям - False.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# В столбце "kitchen_area" количество пропущенных значений площади кухни в квартирах занимает около 9,6 %.
# Данные просто не заполнили, оставим NaN.

# %% [markdown]
# В столбце "balcony" количество пропущенных значений балконов в квартирах занимает около 48,6 %.
# Скорее всего балконов в этих квартирах нет, для расчетов заменим их ноль.

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# В столбце "locality_name" количество пропущенных значений названий населённых пунктов занимает около 0,2 %.
# Данные просто не заполнили, оставим NaN.

# %% [markdown]
# В столбцах "airports_nearest" и "city_centers_nearest" (расстояние до ближайшего аэропорта в метрах (м) и
# расстояние до центра города (м)) количество пропущенных значений почти одинаковое - 5542 и 5519. (около 23 %).
# Вероятнее всего аэропортов рядом нет и центр города не близко. Данные просто не заполнили, оставим NaN.

# %% [markdown]
# В столбцах "parks_around_3000" и "ponds_around_3000" (число парков в радиусе 3 км и число водоёмов в радиусе 3 км) количество пропущенных значений одинаковые - 5518 и 5518. (около 23 %).
# Вероятнее всего на самом деле, в радиусе 3 км нет ни парков, ни водоёмов. Данные просто не заполнили, оставим NaN.

# %% [markdown]
# В столбцах "parks_nearest" и "ponds_nearest" (расстояние до ближайшего парка (м) и расстояние до ближайшего водоёма (м)) количество пропущенных значений почти одинаковое - 15620 и 14589. (около 65,9 и 61,5 %).
# Вероятнее всего на самом деле рядом нет парков и водоёмов.
# Данные просто не заполнили, оставим NaN.

# %% [markdown]
# В столбце "days_exposition" (количество дней размещения объявления (от публикации до снятия)) количество пропущенных значений (около 13,4 %). Данные просто не заполнили, оставим NaN.

# %% [markdown]
#  Проверим количество пропущенных значений для каждого столбца.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1870
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2231
# balcony                     0
# locality_name              48
# airports_nearest         5532
# city_centers_nearest     5509
# parks_around_3000        5508
# parks_nearest           15568
# ponds_around_3000        5508
# ponds_nearest           14552
# days_exposition          3172
# dtype: int64

# %% [markdown]
# Как и ожидалось, в столбцах ceiling_height, floors_total, is_apartment, balcony пропущеных значений не стало.

# %% [markdown]
# Поменяем тип данных для:
# last_price - на int64,
# first_day_exposition - на datetime64,
# floors_total - на int8,
# is_apartment - на bool,
# balcony - на int8.
# Изменения на тип int8, int64 и datetime64 вызваны необходимостью удобства работы и экономии памяти.

# %%
data['last_price'] = data['last_price'].astype('int64')

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S')

# %%
data['floors_total'] = data['floors_total'].astype('int8')

# %%
data['balcony'] = data['balcony'].astype('int8')

# %%
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            2.65            14          NaN      9         False  ...
# 4            3.03            14         32.0     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        0  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Выведем основную информацию об обновленном датафрейме.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  int64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  datetime64[ns]
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        23613 non-null  float64
#  6   floors_total          23613 non-null  int8
#  7   living_area           21743 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  bool
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          21382 non-null  float64
#  13  balcony               23613 non-null  int8
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Изучение уникальных значений в столбце "locality_name"

# %% [markdown]
# Количество всех уникальных значений в столбце "locality_name"

# %%
data['locality_name'].nunique()
# Out:
# 364

# %% [markdown]
# Приводим все названия к нижнему регистру

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %% [markdown]
# Заменяем все буквы "ё" на "е" в словах названий

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')

# %% [markdown]
# Заменим слово "городской поселок" на "поселок городского типа"

# %%
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')

# %% [markdown]
# Проверка наличие явных дубликатов

# %%
print('Количетво явных дубликатов:', data.duplicated().sum())
# Out:
# Количетво явных дубликатов: 0

# %% [markdown]
# Проверим еще раз количество всех уникальных значений в столбце "locality_name"

# %%
data['locality_name'].nunique()
# Out:
# 323

# %% [markdown]
# Изучим распределение значений в данных (удалим выбросы)

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23613.000000  2.361300e+04  23613.000000  23613.000000    23613.000000
# mean       9.874518  6.540555e+06     60.340678      2.071147        2.724581
# std        5.681541  1.090172e+07     35.648988      1.078380        0.990085
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.799000e+06     69.800000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21743.000000  23613.000000  21382.000000  23613.000000
# mean      10.673824     34.462781      5.877313     10.564128      0.593063
# ...

# %% [markdown]
# В столбце "total_images" минимальное значение ноль, максимальное - 50, выглядит правдоподобно, оставим без изменений.

# %% [markdown]
# В столбце "last_price" минимальное значение - 12190 руб., максимальное - 763 млн. руб., выглядит не правдоподобно, проанализируем:

# %%
print('Квартир стоимостью меньше 100.000 руб.:', data.query('last_price < 100000')['last_price'].count())
print('Квартир стоимостью больше 50 млн. руб., но меньше 100 млн. руб.:', data.query('50000000 < last_price < 100000000')['last_price'].count())
print('Квартир стоимостью больше 100 млн. руб.:', data.query('last_price > 100000000')['last_price'].count())
# Out:
# Квартир стоимостью меньше 100.000 руб.: 1
# Квартир стоимостью больше 50 млн. руб., но меньше 100 млн. руб.: 94
# Квартир стоимостью больше 100 млн. руб.: 37

# %% [markdown]
# Количество таких квартир не большое 1+94+37=132 (около 0,55 % от общего количества).
# Для дальнейших расчетов можно пренебречь этими данными. Удалим эти строки.

# %%
data.drop(index=data.query('last_price < 100000').index, inplace=True)
data.drop(index=data.query('last_price > 50000000').index, inplace=True)

# %%
data.hist('last_price', bins = 50, range = (100000, 50000000));
plt.title('last_price (Цена на момент снятия с публикации)')
plt.xlabel('Цена')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "total_area" минимальное значение - 12 кв.м., максимальное - 900 кв.м., проанализируем:

# %%
print('Квартир площадью менее 15 кв.м.:', data.query('total_area < 15')['total_area'].count())
print('Квартир площадью более 300 кв.м., но менее 500 кв.м.:', data.query('300 < total_area < 500')['total_area'].count())
print('Квартир площадью более 500 кв.м.:', data.query('total_area > 500')['total_area'].count())
# Out:
# Квартир площадью менее 15 кв.м.: 6
# Квартир площадью более 300 кв.м., но менее 500 кв.м.: 28
# Квартир площадью более 500 кв.м.: 1

# %% [markdown]
# Квартиры c площадью менее 15 кв.м. кажутся правдоподобными, оставляем их.
# Квартиры c площадью более 300 кв.м. относятся к элитным и их не много, можно для расчетов ими пренебречь.

# %%
data.drop(index=data.query('total_area > 300').index, inplace=True)

# %%
data.hist('total_area', bins = 50, range = (10, 300));
plt.title('total_area (Общая площадь квартиры в квадратных метрах)')
plt.xlabel('Площадь квартиры')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "rooms" минимальное значение - 0 комнат, максимальное - 19 комнат, проанализируем:

# %%
print('Ноль комнат в квартире:', data.query('rooms == 0')['rooms'].count())
print('Ноль комнат в квартире и студии:', data.query('rooms == 0 and studio')['rooms'].count()) 
print('Ноль комнат в квартире и апартаменты:', data.query('rooms == 0 and is_apartment')['rooms'].count()) 
print('Ноль комнат в квартире и свободная планировка:', data.query('rooms == 0 and open_plan')['rooms'].count())
print('Ноль комнат в квартире, не апартаменты и не свободная планировка:', data.query('rooms == 0 and ~open_plan and ~studio')['rooms'].count())
# Out:
# Ноль комнат в квартире: 193
# Ноль комнат в квартире и студии: 135
# Ноль комнат в квартире и апартаменты: 0
# Ноль комнат в квартире и свободная планировка: 58
# Ноль комнат в квартире, не апартаменты и не свободная планировка: 0

# %% [markdown]
# По результатам анализа видно, что 196 квартир это студии и квартиры со свободной планировкой, оставляем их.
# Проверим, сколько квартир с более 7 комнат.

# %%
print('Квартиры с более 7 комнатами:', data.query('rooms > 7')['rooms'].count())
# Out:
# Квартиры с более 7 комнатами: 18

# %% [markdown]
# Квартиры c более 7 комнатами относятся к элитным и их не много, можно для расчетов ими пренебречь.

# %%
data.drop(index=data.query('rooms > 7').index, inplace=True)

# %%
data.hist('rooms', bins = 50, range = (0, 7));
plt.title('rooms (Число комнат)')
plt.xlabel('Число комнат')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "ceiling_height" минимальное значение высоты потолков - 1 метр, максимальное - 100 метров.
# Минимальная высота до потолка должна быть не менее 2,5 метров, все что меньше можно удалить. Проанализируем:

# %%
print('Высота потолков менее 2,5 м.:', data.query('ceiling_height < 2.5')['ceiling_height'].count())
print('Высота потолков более 3 м., но менее 5 м.:', data.query('3 < ceiling_height < 5')['ceiling_height'].count())
print('Высота потолков более 5 м.:', data.query('ceiling_height > 5')['ceiling_height'].count())
# Out:
# Высота потолков менее 2,5 м.: 73
# Высота потолков более 3 м., но менее 5 м.: 1410
# Высота потолков более 5 м.: 32

# %% [markdown]
# Квартир c высотой потолка менее 2,5 м. - 73, можно для расчетов ими пренебречь.
# Квартир c высотой потолка от 3 м. до 5 м. - 1410, кажутся правдоподобными, оставляем их.
# Квартир c высотой потолка более 5 м. - 32, кажутся не правдоподобными, их не много, можно для расчетов ими пренебречь.

# %%
data.drop(index=data.query('ceiling_height < 2.5').index, inplace=True)
data.drop(index=data.query('ceiling_height > 5').index, inplace=True)

# %%
data.hist('ceiling_height', bins = 30, range = (2, 5));
plt.title('ceiling_height (Высота потолков, м)')
plt.xlabel('Высота потолков')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "floors_total" минимальное значение этажей в доме - 1, максимальное - 60.
# Проанализируем:

# %%
print('Количество этажей в доме более 35:', data.query('floors_total > 35')['floors_total'].count())
# Out:
# Количество этажей в доме более 35: 4

# %% [markdown]
# Похоже на правду. Оставляем значения.

# %%
data.hist('floors_total', bins = 30, range = (0, 60));
plt.title('floors_total (Всего этажей в доме)')
plt.xlabel('Количество этажей в доме')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "living_area" минимальное значение жилой площади - 2 кв.м., максимальное - 409,7 кв.м.
# Проанализируем:

# %%
print('Количество квартир с жилой площадью менее 5 кв.м.:', data.query('living_area < 5')['living_area'].count())
print('Количество квартир с жилой площадью более 175 кв.м:', data.query('living_area > 175')['living_area'].count())
# Out:
# Количество квартир с жилой площадью менее 5 кв.м.: 3
# Количество квартир с жилой площадью более 175 кв.м: 10

# %% [markdown]
# Этим количеством квартир для расчетов можно пренебречь.

# %%
data.drop(index=data.query('living_area < 5').index, inplace=True)
data.drop(index=data.query('living_area > 175').index, inplace=True)

# %%
data.hist('living_area', bins = 40, range = (0, 200));
plt.title('living_area (Жилая площадь в кв.м.)')
plt.xlabel('Жилая площадь')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "floor" минимальное значение этажа квартиры - 1 этаж, максимальное - 33 этаж.
# Значения выглядят правдоподобно. Оставляем без изменений.

# %%
data.hist('floor', bins = 40, range = (0, 40));
plt.title('floor (Этаж)')
plt.xlabel('Этаж')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "kitchen_area" минимальное значение площади кухни - 1,3 кв.м., максимальное - 112 кв.м.
# Проанализируем:

# %%
print('Площадь кухни квартиры менее 4 кв.м.:', data.query('kitchen_area < 4')['kitchen_area'].count())
print('Площадь кухни квартиры более 60 кв.м.:', data.query('kitchen_area > 60')['kitchen_area'].count())
# Out:
# Площадь кухни квартиры менее 4 кв.м.: 27
# Площадь кухни квартиры более 60 кв.м.: 9

# %% [markdown]
# Квартиры с площадью кухни менее 4 кв.м. - возможно это студии. Эти значения можно оставить.
# Квартиры с площадью кухни более 60 кв.м. - это скорее всего в элитном жилье, этими значениями можно пренебречь.

# %%
data.drop(index=data.query('kitchen_area > 60').index, inplace=True)
data.hist('kitchen_area', bins = 30, range = (0, 60));
plt.title('kitchen_area (Площадь кухни в кв.м.)')
plt.xlabel('Площадь кухни')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "balcony" минимальное значение - 0, максимальное - 5.
# Выглядит правдоподобно. Оставляем без изменений.

# %%
data.hist('balcony', bins = 6, range = (0, 6));
plt.title('balcony (Число балконов)')
plt.xlabel('Число балконов')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "airports_nearest" минимальное значение - 0 м., максимальное - 84869 м.
# Проанализируем:

# %%
print('Расстояние до ближайшего аэропорта менее 5000 м.:', data.query('airports_nearest < 5000')['airports_nearest'].count())
print('Расстояние до ближайшего аэропорта более 80000 м.:', data.query('airports_nearest > 80000')['airports_nearest'].count())
# Out:
# Расстояние до ближайшего аэропорта менее 5000 м.: 1
# Расстояние до ближайшего аэропорта более 80000 м.: 7

# %% [markdown]
# Количеством 1 (значение ноль метров) и количеством 7 можно пренебречь.

# %%
data.drop(index=data.query('airports_nearest < 5000').index, inplace=True)
data.drop(index=data.query('airports_nearest > 80000').index, inplace=True)
data.hist('airports_nearest', bins = 30, range = (100, 85000));
plt.title('airports_nearest (Расстояние до ближайшего аэропорта в метрах)')
plt.xlabel('Расстояние до ближайшего аэропорта')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "city_centers_nearest" минимальное значение - 181 м., максимальное - 65968 м.
# Проанализируем:

# %%
print('Расстояние до центра города менее 200 м.:', data.query('city_centers_nearest < 200')['city_centers_nearest'].count())
print('Расстояние до центра города более 55000 м.:', data.query('city_centers_nearest > 55000')['city_centers_nearest'].count())
# Out:
# Расстояние до центра города менее 200 м.: 1
# Расстояние до центра города более 55000 м.: 5

# %% [markdown]
# Похоже на правду. Но этими значениями можно пренебречь.

# %%
data.drop(index=data.query('city_centers_nearest < 200').index, inplace=True)
data.drop(index=data.query('city_centers_nearest > 55000').index, inplace=True)
data.hist('city_centers_nearest', bins = 30, range = (100, 60000));
plt.title('city_centers_nearest (расстояние до центра города в метрах)')
plt.xlabel('Расстояние до центра города')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "parks_around_3000" (число парков в радиусе 3 км.) минимальное значение - 0, максимальное - 3.
# Выглядит правдоподобно. Оставляем без изменений.

# %%
data.hist('parks_around_3000', bins = 3, range = (0, 3));
plt.title('parks_around_3000 (Число парков в радиусе 3 км)')
plt.xlabel('Число парков в радиусе 3 км')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "parks_nearest" (расстояние до ближайшего парка в м.) минимальное значение - 1, максимальное - 3190.

# %%
print('Расстояние до ближайшего парка менее 10 м.:', data.query('parks_nearest < 10')['parks_nearest'].count())
print('Расстояние до ближайшего парка более 2000 м.:', data.query('parks_nearest > 2000')['parks_nearest'].count())
# Out:
# Расстояние до ближайшего парка менее 10 м.: 6
# Расстояние до ближайшего парка более 2000 м.: 113

# %% [markdown]
# Этими данными можно пренебречь.

# %%
data.drop(index=data.query('parks_nearest < 10').index, inplace=True)
data.drop(index=data.query('parks_nearest > 2000').index, inplace=True)
data.hist('parks_nearest', bins = 40, range = (10, 2000));
plt.title('parks_nearest (Расстояние до ближайшего парка (м))')
plt.xlabel('Расстояние до ближайшего парка')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "ponds_around_3000" (число водоёмов в радиусе 3 км.) минимальное значение - 0, максимальное - 3.
# Выглядит правдоподобно. Оставляем без изменений.

# %%
data.hist('ponds_around_3000', bins = 3, range = (0, 3));
plt.title('ponds_around_3000 (Число водоёмов в радиусе 3 км.)')
plt.xlabel('Число водоёмов в радиусе 3 км.')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "ponds_nearest" (расстояние до ближайшего водоёма в м.) минимальное значение - 13, максимальное - 1344.

# %%
print('Расстояние до ближайшего водоёма менее 50 м.:', data.query('ponds_nearest < 50')['ponds_nearest'].count())
print('Расстояние до ближайшего водоёма более 1200 м.:', data.query('ponds_nearest > 1200')['ponds_nearest'].count())
# Out:
# Расстояние до ближайшего водоёма менее 50 м.: 139
# Расстояние до ближайшего водоёма более 1200 м.: 52

# %% [markdown]
# Похоже на правду. Оставим без изменений.

# %%
data.hist('ponds_nearest', bins = 40, range = (10, 1400));
plt.title('ponds_nearest (Расстояние до ближайшего водоёма (м))')
plt.xlabel('Расстояние до ближайшего водоёма')
plt.ylabel('Частота');

# %% [markdown]
# В столбце "days_exposition" (количество дней размещения объявления (от публикации до снятия)) минимальное значение - 1, максимальное - 1580.

# %%
print('Количество дней размещения объявления менее 3 дней:', data.query('days_exposition < 3')['days_exposition'].count())
print('Количество дней размещения объявления менее 10 дня:', data.query('days_exposition < 10')['days_exposition'].count())
print('Количество дней размещения объявления более 365 дней:', data.query('days_exposition > 365')['days_exposition'].count())
# Out:
# Количество дней размещения объявления менее 3 дней: 4
# Количество дней размещения объявления менее 10 дня: 1111
# Количество дней размещения объявления более 365 дней: 2961

# %% [markdown]
# Значения количества дней размещения объявления более 365 дней (более года) удалим, так как эти квартиры очень долго продаются и учитывать их при анализе не целесообразно, иначе они будут искажать средние и медианные значения.

# %%
data.drop(index=data.query('days_exposition > 365').index, inplace=True)
data.hist('days_exposition', bins = 36, range = (0, 365));
plt.title('days_exposition\n (Количество дней размещения объявления, от публикации до снятия)')
plt.xlabel('Количество дней размещения объявления')
plt.ylabel('Частота');

# %% [markdown]
# Cбросим индексацию после удаления строк.

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Выведем первые пять строк обновленного датафрейма.

# %%
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2             2    10000000       100.0           2018-06-19      2
# 3            10     2890000        30.4           2018-09-10      1
# 4             6     3700000        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            3.03            14         32.0     13         False  ...
# 3            2.65            12         14.4      5         False  ...
# 4            2.65            26         10.6      6         False  ...
#
#    kitchen_area  balcony                    locality_name  airports_nearest  \
# ...

# %% [markdown]
#  Выведем основную информацию об обновленном датафрейме.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20213 entries, 0 to 20212
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20213 non-null  int64
#  1   last_price            20213 non-null  int64
#  2   total_area            20213 non-null  float64
#  3   first_day_exposition  20213 non-null  datetime64[ns]
#  4   rooms                 20213 non-null  int64
#  5   ceiling_height        20213 non-null  float64
#  6   floors_total          20213 non-null  int8
#  7   living_area           18541 non-null  float64
#  8   floor                 20213 non-null  int64
#  9   is_apartment          20213 non-null  bool
#  10  studio                20213 non-null  bool
#  11  open_plan             20213 non-null  bool
#  12  kitchen_area          18231 non-null  float64
#  13  balcony               20213 non-null  int8
#  14  locality_name         20175 non-null  object
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  20213.000000  2.021300e+04  20213.000000  20213.000000    20213.000000
# mean       9.967298  5.799758e+06     57.598609      2.018503        2.688322
# std        5.683865  4.629855e+06     27.151237      0.998194        0.201470
# min        0.000000  4.300000e+05     12.000000      0.000000        2.500000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%       10.000000  4.570000e+06     51.000000      2.000000        2.650000
# 75%       14.000000  6.500000e+06     67.400000      3.000000        2.700000
# max       50.000000  5.000000e+07    295.000000      7.000000        5.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  20213.000000  18541.000000  20213.000000  18231.000000  20213.000000
# mean      10.806610     32.931572      5.935438     10.251337      0.600455
# ...

# %% [markdown]
# **Вывод: Мы осуществили предобработку данных, а именно нашли и изучили пропущенные значения в столбцах, заполнили где возможно  пропущенные значения, в некоторых столбцах изменили тип данных, изучили уникальные значения в столбце с названиями и устранили неявные дубликаты, нашли и устранили редкие и аномальные значения.**

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в таблицу столбец с ценой одного квадратного метра.

# %%
data['price_per_square_meter'] = data['last_price'] / data['total_area']

# %% [markdown]
#  Выведем основную информацию об обновленном датафрейме.

# %% [markdown]
# Добавим в таблицу столбец с днем публикации объявления (0 - понедельник, 1 - вторник и т.д.).

# %%
data['day_of_publication'] = data['first_day_exposition'].dt.dayofweek

# %% [markdown]
# Добавим в таблицу столбец с месяцем публикации объявления.

# %%
data['month'] = data['first_day_exposition'].dt.month

# %% [markdown]
# Добавим в таблицу столбец с годом публикации объявления. Выведем основную информацию об обновленном датафрейме.

# %%
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Добавим в таблицу столбец с типом этажа квартиры (значения — «первый», «последний», «другой»)

# %%
data['floor_category'] = data.apply(
    lambda x: 'первый' if (x.floor == 1) 
    else ('последний' if (x.floor == x.floors_total) & isinstance(x.floors_total,int) 
    else 'другой'), axis=1
)

# %% [markdown]
# Добавим в таблицу столбец с типом этажа квартиры с цифровым значением (1 — «первый», 3 - «последний», 2 - «другой»: для возможности проведения расчетов)

# %%
data['floor_category_digit'] = data.apply(
    lambda x: 1 if (x.floor == 1) 
    else (3 if (x.floor == x.floors_total) & isinstance(x.floors_total,int) 
    else 2), axis=1
)

# %% [markdown]
#  Добавим в таблицу столбец с расстоянием в км до центра города

# %%
data['city_centers_nearest_km'] = round(data['city_centers_nearest'] / 1000)

# %% [markdown]
# Выведем первые пять строк обновленного датафрейма.

# %%
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2             2    10000000       100.0           2018-06-19      2
# 3            10     2890000        30.4           2018-09-10      1
# 4             6     3700000        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            3.03            14         32.0     13         False  ...
# 3            2.65            12         14.4      5         False  ...
# 4            2.65            26         10.6      6         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  price_per_square_meter  \
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  20213.000000  2.021300e+04  20213.000000  20213.000000    20213.000000
# mean       9.967298  5.799758e+06     57.598609      2.018503        2.688322
# std        5.683865  4.629855e+06     27.151237      0.998194        0.201470
# min        0.000000  4.300000e+05     12.000000      0.000000        2.500000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%       10.000000  4.570000e+06     51.000000      2.000000        2.650000
# 75%       14.000000  6.500000e+06     67.400000      3.000000        2.700000
# max       50.000000  5.000000e+07    295.000000      7.000000        5.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  20213.000000  18541.000000  20213.000000  18231.000000  20213.000000
# mean      10.806610     32.931572      5.935438     10.251337      0.600455
# ...

# %% [markdown]
# **Вывод:
# Добавили в таблицу новые столбцы со следующими параметрами:
# цена одного квадратного метра;
# день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# месяц публикации объявления;
# год публикации объявления;
# тип этажа квартиры (значения — «первый», «последний», «другой»);
# расстояние до центра города в километрах (перевели их из м в км и округлили до целых значений).**

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Построим гистограммы для числовых значений датафрейма.

# %% [markdown]
# Построим гистограмму для total_images (число фотографий квартиры в объявлении).

# %%
data.hist('total_images', bins = 30, range = (0, 30));
plt.title('total_images (Число фотографий квартиры в объявлении)')
plt.xlabel('Число фотографий квартиры в объявлении')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: На гистограмме видим 3 пиковых значения - значение "0", "10" и "20" (0 - это объявления без фотографий квартиры; а почему именно значения 10 и 20 пиковые, возможно из-за рекомендаций системы пользователю, чтобы размещать 10 или 20 фотографий).

# %% [markdown]
# Построим гистограмму для last_price (цены на момент снятия с публикации объявления).

# %%
data.hist('last_price', bins = 30, range = (0, 30000000));
plt.title('last_price (Цена на момент снятия с публикации объявления)')
plt.xlabel('Цена на момент снятия с публикации объявления')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются объявления с ценами квартир от 2 млн.руб. до 7 млн.руб.

# %% [markdown]
# Построим гистограмму для "total_area" (общей площади квартиры в квадратных метрах (м²)).

# %%
data.hist('total_area', bins = 25, range = (0, 250));
plt.title('total_area (Общая площадь квартиры в кв.м.)')
plt.xlabel('Общая площадь квартиры в кв.м.')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются объявления с общей площадью квартиры 30 м² до 60 м².

# %% [markdown]
# Построим гистограмму для "rooms" (число комнат в квартире).

# %%
data.hist('rooms', bins = 40, range = (0, 8)); 
plt.title('rooms (Число комнат в квартире)')
plt.xlabel('Число комнат в квартире')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются объявления о продаже одно- и двухкомнатных квартир, реже - трехкомнатных.

# %% [markdown]
# Построим гистограмму для "ceiling_height" (высоте потолков в квартирах).

# %%
data.hist('ceiling_height', bins = 30, range = (2, 5));
plt.title('ceiling_height (Высота потолков в квартире (м))')
plt.xlabel('Высота потолков в квартире')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются квартиры с высотой потолков от 2,5 м до 3,1 м.

# %% [markdown]
# Построим гистограмму для "floors_total" (количество этажей в доме).

# %%
data.hist('floors_total', bins = 30, range = (0, 30));
plt.title('floors_total (Количество этажей в доме)')
plt.xlabel('Количество этажей в доме')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются квартиры в 5-6 этажных и в 9-10 этажных домах.

# %% [markdown]
# Построим гистограмму для "living_area" (жилой площади в квадратных метрах (м²)).

# %%
data.hist('living_area', bins = 30, range = (0, 150));
plt.title('living_area (Жилая площадь в кв.м.)')
plt.xlabel('Жилая площадь в кв.м.')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются квартиры с жилой площадью 15-20 м² (скорее всего в однокомнатных квартирах), реже 25-35 м² (скорее всего в двух- и трехкомнатных квартирах).

# %% [markdown]
# Построим гистограмму для "floor" (этаж расположения квартиры).

# %%
data.hist('floor', bins = 30, range = (0, 30));
plt.title('floor (Этаж расположения квартиры)')
plt.xlabel('Этаж')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются квартиры с 1 эт. до 6 эт. (скорее всего в старом фонде).

# %% [markdown]
# Построим гистограмму для "kitchen_area" (площадь кухни).

# %%
data.hist('kitchen_area', bins = 30, range = (0, 30));
plt.title('kitchen_area (Площадь кухни)')
plt.xlabel('Площадь кухни')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Чаще всего встречаются кухни площадью от 6 м² до 12 м².

# %% [markdown]
# Построим гистограмму для "airports_nearest" (расстояние до ближайшего аэропорта в метрах (м))

# %%
data.hist('airports_nearest', bins = 30, range = (0, 60000));
plt.title('airports_nearest (Расстояние до ближайшего аэропорта в метрах)')
plt.xlabel('Расстояние до ближайшего аэропорта в метрах')
plt.ylabel('Частота');

# %% [markdown]
# Известно, что в Санкт-Петербурге 2 гражданских аэропорта:
# 1) самый главный аэропорт Питера - Пулково (он имеет 2 терминала и выполняет роль главных воздушных ворот города).
# 2) есть также частный аэродром "Бычье Поле", расположенный недалеко от Кронштадта.
# Вывод: Гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего аэропорта на расстоянии 10-28 км. и 32-38 км.

# %% [markdown]
# Построим гистограмму для "city_centers_nearest" (расстояние до центра города (м))

# %%
data.hist('city_centers_nearest', bins = 30, range = (0, 60000));
plt.title('city_centers_nearest (Расстояние до центра города в метрах)')
plt.xlabel('Расстояние до центра города')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего центра на расстоянии 10-18 км. (с выбросом 4-6 км.).

# %% [markdown]
# Построим гистограмму для "parks_nearest" (расстояние до ближайшего парка (м))

# %%
data.hist('parks_nearest', bins = 40, range = (0, 2000));
plt.title('parks_nearest (Расстояние до ближайшего парка (м))')
plt.xlabel('Расстояние до ближайшего парка')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего парка на расстоянии 150-700 м.

# %% [markdown]
# Построим гистограмму для "ponds_nearest" (расстояние до ближайшего водоема (м))

# %%
data.hist('ponds_nearest', bins = 30, range = (0, 1500));
plt.title('ponds_nearest (Расстояние до ближайшего водоема (м))')
plt.xlabel('Расстояние до ближайшего водоема')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего водоема на расстоянии 50-1000 м.

# %% [markdown]
# Построим гистограмму для "days_exposition" (сколько дней было размещено объявление (от публикации до снятия))

# %%
data.hist('days_exposition', bins = 30, range = (0, 300));
plt.title('days_exposition (Количество дней размещения объявления (от публикации до снятия))')
plt.xlabel('Количество дней размещения объявления')
plt.ylabel('Частота');

# %% [markdown]
# Вывод: Гистограмма показывает, что чаще объявления размещаются на пиковых значениях от 0 до 50 дней (с выбросом 45-50 дней и 55-60 дней).

# %% [markdown]
# Гистограмма цены одного квадратного метра.

# %%
data.hist('price_per_square_meter', bins = 40, range = (0, 200000));
plt.title('price_per_square_meter (Цена квадратного метра, руб.)')
plt.xlabel('Цена квадратного метра')
plt.ylabel('Частота');

# %% [markdown]
# Гистограмма - день недели публикации объявления.

# %%
data.hist('day_of_publication', bins = 7, range = (0, 7));
plt.title('day_of_publication (День недели публикации объявления)')
plt.xlabel('День недели публикации объявления')
plt.ylabel('Частота');

# %% [markdown]
# Гистограмма - месяц публикации объявления.

# %%
data.hist('month', bins = 12, range = (1, 13))
plt.title('month (Месяц публикации объявления)')
plt.xlabel('Месяц публикации объявления')
plt.ylabel('Частота');

# %% [markdown]
# Гистограмма - год публикации объявления.

# %%
data.hist('year', bins = 11, range = (2010, 2021));
plt.title('year (Год публикации объявления)')
plt.xlabel('Год публикации объявления')
plt.ylabel('Частота');

# %% [markdown]
#  Гистограмма - тип этажа квартиры.

# %%
data.hist('floor_category_digit', bins = 3, range = (1, 4));
plt.title('floor_category_digit (Тип этажа квартиры)')
plt.xlabel('Тип этажа квартиры')
plt.ylabel('Частота');

# %% [markdown]
# **Выводы по гистограммам столбцов датафрейма:**
#
# 1. В столбце "total_images" (число фотографий квартиры в объявлении) - на гистограмме видим 3 пиковых значения - значение "0", "10" и "20" (0 - это объявления без фотографий квартиры; а почему именно значения 10 и 20 пиковые, возможно из-за рекомендаций системы пользователю, чтобы размещать 10 или 20 фотографий);
# 2. В столбце "last_price" (цены на момент снятия с публикации объявления) - чаще всего встречаются объявления с ценами квартир от 2 млн.руб. до 7 млн.руб.
# 3. В столбце "total_area" (общей площади квартиры в квадратных метрах (м²)) -  чаще всего встречаются объявления с общей площадью квартиры 30 м² до 60 м², что не удивительно, ведь эти площади самые доступные к покупке.
# 4. В столбце "day_of_publication" (день недели публикации объявления) - чаще размещаются объявления в будни, реже в выходные.
# 5. В столбце "month" (месяц публикации объявления) - видим два пика, чаще размещают объявления в феврале-марте-апреле и в октябре-ноябре.
# 6. В столбце "year" (год публикации объявления) - видим активность в 2017-2019 годах.
# 7. В столбце "rooms" (комнаты в квартире) - чаще всего встречаются объявления продаж одно- и двухкомнатных квартир, реже трехкомнатных, а остальных еще реже.
# 8. В столбце "ceiling_height" (высота потолков в квартире) - чаще всего встречаются квартиры с высотой потолков от 2,5 м до 3,1 м.
# 9. В столбце "floors_total" (количество этажей в доме) - чаще всего встречаются квартиры в 5-6 этажных и в 9-10 этажных домах, что не удивительно, ведь таких домов очень много во всех городах нашей страны.
# 10.  В столбце "living_area" (жилая площадь квартиры) - чаще всего встречаются квартиры с жилой площадью 15-20 м² (скорее всего в однокомнатных квартирах), реже 25-35 м² (скорее всего в двух- и трехкомнатных квартирах).
# 11. В столбце "floor" (этаж расположения квартиры) - чаще всего встречаются квартиры с 1 эт. до 6 эт. (скорее всего в старом фонде).
# 12. В столбце "kitchen_area" (площадь кухни) - чаще всего встречаются кухни в квартирах площадью от 6 м² до 12 м² (похоже на правду).
# 13. В столбце "balcony" (количество балконов) - чаще встречаются квартиры с 1 балконом, но и не редки случаи вариантов без балкона и с 2-мя балконами.
# 14. В столбце "airports_nearest" (расстояние до ближайшего аэропорта) - гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего аэропорта на расстоянии 10-28 км. и 30-38 км.
# 15. В столбце "ponds_nearest" (расстояние до ближайшего водоёма) - гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего водоема на расстоянии 200-700 м., не удивительно, ведь город Санкт-Петербург расположен на месте, окруженном водоемами.
# 16. В столбце "parks_nearest" (расстояние до ближайшего парка) - гистограмма показывает, что чаще продаваемые квартиры находятся от ближайшего парка на расстоянии 150-700 м.
# 17. В столбце "parks_around_3000" (число парков в радиусе 3 км) - чаще встречаются объявления с около нулевым значением водоемов в радиусе 3000 метров от продаваемой квартиры.
# 18. В столбце "ponds_around_3000" (число водоемов в радиусе 3 км.) - чаще встречаются объявления с около нулевым значением водоемов в радиусе 3000 метров от продаваемой квартиры.
# 19. В столбце "days_exposition" (сколько дней было размещено объявление (от публикации до снятия)) - чаще объявления размещаются на пиковых значениях от 0 до 50 дней (с выбросом 45-50 дней и 55-60 дней). Два месяца очень хороший срок для продажи недвижимости.
# 20. В столбце "price_per_square_meter" (стоимости одного квадратного метра) - явно виден пик на графике в дианазоне цены 80000-110000 руб. за кв.м.
# 21. В столбце "floor_category_digit" (тип этажа квартиры) - крайние нижние и верхние этажи встречаются редко, чаще - средние этажи.

# %% [markdown]
# Изучаем "days_exposition" (насколько быстро продавались квартиры).

# %%
print('Среднее время продажи квартиры в днях:', int(data['days_exposition'].mean()))
print('Медианное время продажи квартиры в днях:', int(data['days_exposition'].median()))
# Out:
# Среднее время продажи квартиры в днях: 104
# Медианное время продажи квартиры в днях: 74

# %%
data['days_exposition'].describe()
# Out:
# count    17119.000000
# mean       104.326771
# std         89.274108
# min          1.000000
# 25%         37.000000
# 50%         74.000000
# 75%        153.000000
# max        364.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Cреднее время продажи квартиры составляет 104 дней (около 3,5 месяцев).
# Но если рассматривать медиану - то 74 дня (около 2,5 месяцев).
# Все это потому, что на величину среднего значения оказывает длинный хвост - квартиры, которые долго продаются.
# Также обратив внимание на 25-й и 75-й процентили, можно сделать вывод, что: быстрые продажи - это около месяца (37 дней), средние продажи - около 2,5 месяцев (74 дня), долгая продажа - около полугода (153 дня) и очень долгая продажа - более 6 месяцев.

# %%
data['days_exposition'].hist(bins = 36, range = (0, 365));
plt.title('days_exposition (Скорость продажи квартиры)')
plt.xlabel('Скорость продажи квартиры')
plt.ylabel('Частота');

# %% [markdown]
# Уберем значения ноль из гистограммы

# %%
data['days_exposition'].hist(bins = 36, range = (1, 365)); 
plt.title('days_exposition (Скорость продажи квартиры)')
plt.xlabel('Скорость продажи квартиры')
plt.ylabel('Частота');

# %% [markdown]
# Заметил небольшую разницу в форме гистограммы изменив всего лишь на единицу начало отсчета (в одном случае range = (1, 365), а в другом случае range = (0, 365)). Это еще раз доказывает, что нужно внимательно работать с данными :) Мы конечно же будем использовать для анализа гистограмму с range = (0, 365).

# %% [markdown]
# Выброс в районе 50 дней возможно связан с обновлением рекламы.

# %% [markdown]
# Посчитаем какие факторы больше всего влияют на общую (полную) стоимость объекта.

# %%
list_for_graph = ['total_area',
                  'living_area',
                  'kitchen_area',
                  'rooms',
                  'floor_category_digit',
                  'day_of_publication',
                  'month',
                  'year']

for entry in list_for_graph:
    correlation = data['last_price'].corr(data[entry])
    print(f'Корреляция между last_price и {entry} составляет: {correlation:0.2%}')
# Out:
# Корреляция между last_price и total_area составляет: 77.42%
# Корреляция между last_price и living_area составляет: 66.99%
# Корреляция между last_price и kitchen_area составляет: 58.90%
# Корреляция между last_price и rooms составляет: 48.67%
# Корреляция между last_price и floor_category_digit составляет: 4.88%
# Корреляция между last_price и day_of_publication составляет: -1.27%
# Корреляция между last_price и month составляет: -0.22%
# Корреляция между last_price и year составляет: -1.05%

# %% [markdown]
# Построение графиков по рекомендациям

# %%
data.plot(x='last_price', y='total_area', kind='scatter', alpha=0.2);
plt.title('Диаграмма рассеяния')
plt.xlabel('last_price (цена на момент снятия с публикации, руб.)')
plt.ylabel('total_area (общая площадь квартиры в кв.м.)');

# %%
data.plot(x='last_price', y='living_area', kind='scatter', alpha=0.2);
plt.title('Диаграмма рассеяния')
plt.xlabel('last_price (цена на момент снятия с публикации, руб.)')
plt.ylabel('living_area (жилая площадь квартиры в кв.м.)');

# %%
data.plot(x='last_price', y='kitchen_area', kind='scatter', alpha=0.2);
plt.title('Диаграмма рассеяния')
plt.xlabel('last_price (цена на момент снятия с публикации, руб.)')
plt.ylabel('kitchen_area (площадь кухни квартиры в кв.м.)');

# %%
data.pivot_table(index='rooms', values='last_price').plot(y='last_price', kind='bar');
plt.title('Диаграмма зависимости цены квартиры\n от количества комнат')
plt.xlabel('rooms (число комнат в квартире)')
plt.ylabel('last_price\n (цена на момент снятия с публикации, руб.)');

# %%
data.pivot_table(index='day_of_publication', values='last_price', aggfunc='median').plot(y='last_price', kind='line', title='median');
plt.title('Медианное значение цены квартиры\n от даты размещения (дня недели)');

# %%
data.pivot_table(index='month', values='last_price', aggfunc='median').plot(y='last_price', kind='line', title='median');
plt.title('Медианное значение цены квартиры\n от даты размещения (месяца)');

# %%
data.pivot_table(index='year', values='last_price', aggfunc='median').plot(y='last_price', kind='line', title='median');
plt.title('Медианное значение цены квартиры\n от даты размещения (года)');

# %%
data.pivot_table(index='floor_category',values='last_price').plot(y='last_price', kind='barh');
data.plot(x='last_price', y='floor_category', kind='scatter', alpha=0.2);

# %% [markdown]
# Выводы: На общую стоимость объекта влияют: общей площади; жилой площади; площади кухни; количества комнат.
# На общую стоимость объекта практически не влияют: этаж, на котором расположена квартира; дата размещения (день недели, месяц, год).

# %% [markdown]
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %%
top_10 = data.pivot_table(index='locality_name', values=['last_price','total_area'] ,aggfunc=['sum','count'])
top_10.columns=['last_price_sum','total_area_sum','last_price_count','total_area_count']
top_10.pop('total_area_count')
top_10.sort_values(by=['last_price_count'],ascending=False, inplace=True)
top_10 = top_10.iloc[:10]
top_10['price_per_sq_m'] = top_10['last_price_sum']/top_10['total_area_sum']
top_10.sort_values(by=['price_per_sq_m'],ascending=True, inplace=True)

# %%
top_10
# Out:
#                    last_price_sum  total_area_sum  last_price_count  \
# locality_name
# выборг                  673564000        11566.66               206
# всеволожск             1320708965        19365.06               344
# гатчина                 896294360        13012.42               259
# колпино                1166462246        15836.26               301
# поселок шушары         1621625699        21181.53               394
# поселок мурино         1781592742        21331.18               491
# поселок парголово      1288732309        14828.65               287
# деревня кудрово        1107718717        12172.36               259
# пушкин                 1894848364        18135.98               316
# санкт-петербург       92982641586       810316.62             13302
#
#                    price_per_sq_m
# locality_name
# выборг               58233.232411
# всеволожск           68200.613115
# гатчина              68879.913191
# колпино              73657.684706
# ...

# %%
top_10['price_per_sq_m'].plot(kind='barh')
plt.title('Средняя цена одного квадратного метра\n в 10 населённых пунктах с наибольшим числом объявлений')
plt.xlabel('price_per_sq_m\n (средняя цена одного квадратного метра)')
plt.ylabel('locality_name\n (название населённого пункта)');

# %%
data.groupby(by='rooms')['rooms'].count().sort_values(ascending=False)
# Out:
# rooms
# 1    7057
# 2    6880
# 3    4863
# 4     915
# 5     225
# 0     177
# 6      63
# 7      33
# Name: rooms, dtype: int64

# %% [markdown]
# Логично, что самая дорогая недвижимость в Санкт-Петербурге.
# В ТОП-10 входят ближайшие к Санкт-Петербургу города.

# %% [markdown]
# Выделем квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра.

# %%
(
    data[data['locality_name']=='санкт-петербург']
    .pivot_table(
        index='city_centers_nearest_km',
        values='last_price',
        aggfunc='mean')
    .plot(kind='bar')
);
plt.title('Стоимость квадратного метра\n в зависимости от расстояния от центра города')
plt.xlabel('city_centers_nearest_km\n (расстояние до центра города, км)')
plt.ylabel('last_price\n (цена на момент снятия с публикации, руб.)');

# %% [markdown]
# Большое значение показывает недвижимость до 2 км. Есть небольшой всплеск на диапазоне 3-7 км.
# Далее цена снижается на расстоянии от 8 км. до 26 км.
# Видим всплеск на 27 км, это явление сложно объяснить.
# Чем дальше недвижимость от центра города, тем дешевле стоимость квадратного метра.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# **В заключении можно сказать, что проделана определенная работа по исследовательскому анализу данных, а именно:**
# 1) Осуществили предобработку данных, а именно нашли и изучили пропущенные значения в столбцах, заполнили где возможно пропущенные значения, в некоторых столбцах изменили тип данных, изучили уникальные значения в столбце с названиями и устранили неявные дубликаты, нашли и устранили редкие и аномальные значения, очистили данные от явных "выбросов".
# 2) Добавили в таблицу новые столбцы со следующими параметрами: цена одного квадратного метра; день недели публикации объявления (0 — понедельник, 1 — вторник и так далее); месяц публикации объявления; год публикации объявления; тип этажа квартиры (значения — «первый», «последний», «другой»); расстояние до центра города в километрах (перевели их из м в км и округлили до целых значений).
# 3) Определили, что на общую стоимость объекта влияют: общая площадь; жилая площадь; площадь кухни; количество комнат. На общую стоимость объекта практически не влияют: этаж, на котором расположена квартира; дата размещения (день недели, месяц, год).
# 4) Выявили, что чем ближе находится квартира к центру города Санкт-Петербург, тем дороже стоимость квадратного метра жилья. Также обнаружили, что в 27 км от центра Санкт-Петербурга есть недвижимость по цене почти равная недвижимости в 8 км. от центра.
# 5) Посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделили населённые пункты с самой высокой и низкой стоимостью квадратного метра. В ТОП-10 стоимости входят в основном ближайшие к Санкт-Петербургу города и самые крупные города области: Пушкин, деревня Кудрово, поселок Парголово, поселок Мурино, поселок Шушары, Колпино, Гатчина, Всеволожск, Выборг.
# 6) Рассчитали разные категории времени продажи квартиры: быстрые продажи - это около месяца (37 дней), средние продажи - около 2,5 месяцев (74 дня), долгая продажа - около полугода (153 дня) и очень долгая продажа - более 6 месяцев.
